# %%
from nltk.corpus import stopwords
from nltk import word_tokenize, sent_tokenize
from string import punctuation
from time import time
import pandas as pd
import numpy as np
from gensim.models import KeyedVectors, Word2Vec
from nltk.stem import WordNetLemmatizer
import os

# %%
stop_words = set(stopwords.words('english'))
def process_sentence(text):
    text = text.replace('/', ' / ')
    text = text.replace('.-', ' .- ')
    text = text.replace("(", " ( ")
    text = text.replace(")", " ) ")
    text = text.replace("-"," - ")
    text = text.replace('.', ' . ')
    text = text.replace('\'', ' \' ')
    lemmatizer = WordNetLemmatizer()

    tokens = [token for token in text.split() if token not in punctuation and token not in stop_words]
    tokens = [token.lower() if not token.startswith("Gene_") else token for token in tokens]
    tokens = [lemmatizer.lemmatize(token) if not token.startswith("Gene_") else token  for token in tokens]

    return " ".join(tokens)

# %%
from gensim.models  import KeyedVectors, Word2Vec
from utils import load_embedding
from time import time

t = time()
w2v_cbow_pt = load_embedding("./Embeddings/GO/anc2vec_200.bin", binary=True)
print("Time to load cbow embeddings in mins: ", round(((time() - t)/60.0),2))

t = time()
w2v_sg_pt = load_embedding("./Embeddings/Concepts/bioconceptvec_word2vec_skipgram.bin", binary=True)
print("Time to load skipgram embeddings in mins: ", round(((time() - t)/60.0),2))
# Out:
# embedding loaded from ./Embeddings/GO/anc2vec_200.bin
# Time to load cbow embeddings in mins:  0.0
# embedding loaded from ./Embeddings/Concepts/bioconceptvec_word2vec_skipgram.bin
# Time to load skipgram embeddings in mins:  0.58

# %%
# process pubmed abstract texts and collect all gene_tags into a dictionary
from constants import pbt_path
pubmed_dat_df = pd.read_csv(os.path.join(pbt_path, "pubmed_annotations.tsv"), sep = "\t")
pubmed_data_list = []
pmids = pubmed_dat_df.pmid.unique()

for pmid in pmids:
    data_entry = dict()
    data_entry["pmid"] = pmid
    dat_of_pmid = pubmed_dat_df[pubmed_dat_df["pmid"] == pmid]
    data_entry["genes"] = list(dat_of_pmid.Gene.unique())
    data_entry["gene_eids"] = list(dat_of_pmid.gene_eid.unique())
    data_entry["title"] = dat_of_pmid.title.array[0]
    data_entry["abstract"] = dat_of_pmid.abstract.array[0]
    sentences = sent_tokenize(data_entry["abstract"])
    data_entry["processed_abstract"] = [process_sentence(sent) for sent in sentences]
    pubmed_data_list.append(data_entry)

# %%
# update data entry to associate probable GO terms based on genes found in the abstract
#from utils import get_filtered_uniprot_ids
uniprot_go_dat = pd.read_csv("./Data/UniprotGO/UniprotGO-BP.txt", sep = "\t", header=None)
uniprot_go_dat.columns = ["Uniprot_id", "GO_ids"]
all_uids = uniprot_go_dat.Uniprot_id.to_list()

# %%
from unipressed import IdMappingClient
import time
mappings = []
for uid in all_uids:
    request = IdMappingClient.submit(
        source="UniProtKB_AC-ID",  dest="Gene_Name", ids={uid}
    )
    time.sleep(3.0)
    mappings.extend(list(request.each_result()))
    print(mappings)
# Out:
# [{'from': 'P49848', 'to': 'TAF6'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}, {'from': 'Q01970', 'to': 'PLCB3'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}, {'from': 'Q01970', 'to': 'PLCB3'}, {'from': 'Q9UNS2', 'to': 'COPS3'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}, {'from': 'Q01970', 'to': 'PLCB3'}, {'from': 'Q9UNS2', 'to': 'COPS3'}, {'from': 'P39984', 'to': 'HAT2'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}, {'from': 'Q01970', 'to': 'PLCB3'}, {'from': 'Q9UNS2', 'to': 'COPS3'}, {'from': 'P39984', 'to': 'HAT2'}, {'from': 'Q13588', 'to': 'GRAP'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}, {'from': 'Q01970', 'to': 'PLCB3'}, {'from': 'Q9UNS2', 'to': 'COPS3'}, {'from': 'P39984', 'to': 'HAT2'}, {'from': 'Q13588', 'to': 'GRAP'}, {'from': 'P12643', 'to': 'BMP2'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}, {'from': 'Q01970', 'to': 'PLCB3'}, {'from': 'Q9UNS2', 'to': 'COPS3'}, {'from': 'P39984', 'to': 'HAT2'}, {'from': 'Q13588', 'to': 'GRAP'}, {'from': 'P12643', 'to': 'BMP2'}, {'from': 'Q9UHV7', 'to': 'MED13'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}, {'from': 'Q01970', 'to': 'PLCB3'}, {'from': 'Q9UNS2', 'to': 'COPS3'}, {'from': 'P39984', 'to': 'HAT2'}, {'from': 'Q13588', 'to': 'GRAP'}, {'from': 'P12643', 'to': 'BMP2'}, {'from': 'Q9UHV7', 'to': 'MED13'}, {'from': 'P19474', 'to': 'TRIM21'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}, {'from': 'Q01970', 'to': 'PLCB3'}, {'from': 'Q9UNS2', 'to': 'COPS3'}, {'from': 'P39984', 'to': 'HAT2'}, {'from': 'Q13588', 'to': 'GRAP'}, {'from': 'P12643', 'to': 'BMP2'}, {'from': 'Q9UHV7', 'to': 'MED13'}, {'from': 'P19474', 'to': 'TRIM21'}, {'from': 'Q8WN66', 'to': 'ANG'}]
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}, {'from': 'Q01970', 'to': 'PLCB3'}, {'from': 'Q9UNS2', 'to': 'COPS3'}, {'from': 'P39984', 'to': 'HAT2'}, {'from': 'Q13588', 'to': 'GRAP'}, {'from': 'P12643', 'to': 'BMP2'}, {'from': 'Q9UHV7', 'to': 'MED13'}, {'from': 'P19474', 'to': 'TRIM21'}, {'from': 'Q8WN66', 'to': 'ANG'}, {'from': 'Q9UID5', 'to': 'hREV3'}]
# ...
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}, {'from': 'Q01970', 'to': 'PLCB3'}, {'from': 'Q9UNS2', 'to': 'COPS3'}, {'from': 'P39984', 'to': 'HAT2'}, {'from': 'Q13588', 'to': 'GRAP'}, {'from': 'P12643', 'to': 'BMP2'}, {'from': 'Q9UHV7', 'to': 'MED13'}, {'from': 'P19474', 'to': 'TRIM21'}, {'from': 'Q8WN66', 'to': 'ANG'}, {'from': 'Q9UID5', 'to': 'hREV3'}, {'from': 'Q13325', 'to': 'IFIT5'}, {'from': 'P35658', 'to': 'NUP214'}, {'from': 'Q96J01', 'to': 'THOC3'}, {'from': 'P15056', 'to': 'BRAF'}, {'from': 'Q12788', 'to': 'TBL3'}, {'from': 'P26659', 'to': 'rad15'}, {'from': 'P47224', 'to': 'RABIF'}, {'from': 'P37837', 'to': 'TALDO1'}, {'from': 'P36980', 'to': 'CFHR2'}, {'from': 'Q8TEM1', 'to': 'NUP210'}, {'from': 'P06168', 'to': 'ILV5'}, {'from': 'P55795', 'to': 'HNRNPH2'}, {'from': 'Q99638', 'to': 'RAD9A'}, {'from': 'O75716', 'to': 'STK16'}, {'from': 'Q5D1E8', 'to': 'ZC3H12A'}, {'from': 'Q9NRR4', 'to': 'DROSHA'}, {'from': 'P01906', 'to': 'HLA-DQA2'}, {'from': 'Q14654', 'to': 'KCNJ11'}, {'from': 'O95822', 'to': 'MLYCD'}, {'from': 'Q9UPY8', 'to': 'MAPRE3'}, {'from': 'Q9NYS7', 'to': 'WSB2'}, {'from': 'Q12996', 'to': 'CSTF3'}, {'from': 'P21246', 'to': 'PTN'}, {'from': 'Q96S99', 'to': 'PLEKHF1'}, {'from': 'P22303', 'to': 'ACHE'}, {'from': 'P49711', 'to': 'CTCF'}, {'from': 'O75379', 'to': 'VAMP4'}, {'from': 'O75095', 'to': 'MEGF6'}, {'from': 'P46108', 'to': 'CRK'}, {'from': 'O00167', 'to': 'EYA2'}, {'from': 'P20645', 'to': 'M6PR'}, {'from': 'O95751', 'to': 'LDOC1'}, {'from': 'Q6DKK2', 'to': 'TTC19'}, {'from': 'P13984', 'to': 'GTF2F2'}, {'from': 'O15105', 'to': 'SMAD7'}, {'from': 'Q91ZX6', 'to': 'Senp2'}, {'from': 'P22057', 'to': 'Ptgds'}, {'from': 'Q02223', 'to': 'TNFRSF17'}, {'from': 'Q5XG87', 'to': 'TENT4A'}, {'from': 'P60900', 'to': 'PSMA6'}, {'from': 'Q9ULA0', 'to': 'DNPEP'}, {'from': 'P05549', 'to': 'TFAP2A'}, {'from': 'Q07352', 'to': 'ZFP36L1'}, {'from': 'P60520', 'to': 'GABARAPL2'}, {'from': 'Q8IZ08', 'to': 'GPR135'}, {'from': 'Q96ST3', 'to': 'SIN3A'}, {'from': 'P51617', 'to': 'IRAK1'}, {'from': 'Q9UPZ9', 'to': 'CILK1'}, {'from': 'Q60452', 'to': 'ERCC2'}, {'from': 'Q9NTN9', 'to': 'SEMA4G'}, {'from': 'P78337', 'to': 'PITX1'}, {'from': 'P38631', 'to': 'FKS1'}, {'from': 'Q03135', 'to': 'CAV1'}, {'from': 'P07737', 'to': 'PFN1'}, {'from': 'P04179', 'to': 'SOD2'}, {'from': 'P61421', 'to': 'ATP6V0D1'}, {'from': 'Q15185', 'to': 'PTGES3'}, {'from': 'P0C7A3', 'to': 'Mboat4'}, {'from': 'P40259', 'to': 'CD79B'}, {'from': 'P58215', 'to': 'LOXL3'}, {'from': 'P13693', 'to': 'TPT1'}, {'from': 'Q14692', 'to': 'BMS1'}, {'from': 'Q99 ...
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}, {'from': 'Q01970', 'to': 'PLCB3'}, {'from': 'Q9UNS2', 'to': 'COPS3'}, {'from': 'P39984', 'to': 'HAT2'}, {'from': 'Q13588', 'to': 'GRAP'}, {'from': 'P12643', 'to': 'BMP2'}, {'from': 'Q9UHV7', 'to': 'MED13'}, {'from': 'P19474', 'to': 'TRIM21'}, {'from': 'Q8WN66', 'to': 'ANG'}, {'from': 'Q9UID5', 'to': 'hREV3'}, {'from': 'Q13325', 'to': 'IFIT5'}, {'from': 'P35658', 'to': 'NUP214'}, {'from': 'Q96J01', 'to': 'THOC3'}, {'from': 'P15056', 'to': 'BRAF'}, {'from': 'Q12788', 'to': 'TBL3'}, {'from': 'P26659', 'to': 'rad15'}, {'from': 'P47224', 'to': 'RABIF'}, {'from': 'P37837', 'to': 'TALDO1'}, {'from': 'P36980', 'to': 'CFHR2'}, {'from': 'Q8TEM1', 'to': 'NUP210'}, {'from': 'P06168', 'to': 'ILV5'}, {'from': 'P55795', 'to': 'HNRNPH2'}, {'from': 'Q99638', 'to': 'RAD9A'}, {'from': 'O75716', 'to': 'STK16'}, {'from': 'Q5D1E8', 'to': 'ZC3H12A'}, {'from': 'Q9NRR4', 'to': 'DROSHA'}, {'from': 'P01906', 'to': 'HLA-DQA2'}, {'from': 'Q14654', 'to': 'KCNJ11'}, {'from': 'O95822', 'to': 'MLYCD'}, {'from': 'Q9UPY8', 'to': 'MAPRE3'}, {'from': 'Q9NYS7', 'to': 'WSB2'}, {'from': 'Q12996', 'to': 'CSTF3'}, {'from': 'P21246', 'to': 'PTN'}, {'from': 'Q96S99', 'to': 'PLEKHF1'}, {'from': 'P22303', 'to': 'ACHE'}, {'from': 'P49711', 'to': 'CTCF'}, {'from': 'O75379', 'to': 'VAMP4'}, {'from': 'O75095', 'to': 'MEGF6'}, {'from': 'P46108', 'to': 'CRK'}, {'from': 'O00167', 'to': 'EYA2'}, {'from': 'P20645', 'to': 'M6PR'}, {'from': 'O95751', 'to': 'LDOC1'}, {'from': 'Q6DKK2', 'to': 'TTC19'}, {'from': 'P13984', 'to': 'GTF2F2'}, {'from': 'O15105', 'to': 'SMAD7'}, {'from': 'Q91ZX6', 'to': 'Senp2'}, {'from': 'P22057', 'to': 'Ptgds'}, {'from': 'Q02223', 'to': 'TNFRSF17'}, {'from': 'Q5XG87', 'to': 'TENT4A'}, {'from': 'P60900', 'to': 'PSMA6'}, {'from': 'Q9ULA0', 'to': 'DNPEP'}, {'from': 'P05549', 'to': 'TFAP2A'}, {'from': 'Q07352', 'to': 'ZFP36L1'}, {'from': 'P60520', 'to': 'GABARAPL2'}, {'from': 'Q8IZ08', 'to': 'GPR135'}, {'from': 'Q96ST3', 'to': 'SIN3A'}, {'from': 'P51617', 'to': 'IRAK1'}, {'from': 'Q9UPZ9', 'to': 'CILK1'}, {'from': 'Q60452', 'to': 'ERCC2'}, {'from': 'Q9NTN9', 'to': 'SEMA4G'}, {'from': 'P78337', 'to': 'PITX1'}, {'from': 'P38631', 'to': 'FKS1'}, {'from': 'Q03135', 'to': 'CAV1'}, {'from': 'P07737', 'to': 'PFN1'}, {'from': 'P04179', 'to': 'SOD2'}, {'from': 'P61421', 'to': 'ATP6V0D1'}, {'from': 'Q15185', 'to': 'PTGES3'}, {'from': 'P0C7A3', 'to': 'Mboat4'}, {'from': 'P40259', 'to': 'CD79B'}, {'from': 'P58215', 'to': 'LOXL3'}, {'from': 'P13693', 'to': 'TPT1'}, {'from': 'Q14692', 'to': 'BMS1'}, {'from': 'Q99 ...
# [{'from': 'P49848', 'to': 'TAF6'}, {'from': 'P10275', 'to': 'AR'}, {'from': 'P47897', 'to': 'QARS1'}, {'from': 'P14778', 'to': 'IL1R1'}, {'from': 'Q14781', 'to': 'CBX2'}, {'from': 'O60383', 'to': 'GDF9'}, {'from': 'Q9HBM1', 'to': 'SPC25'}, {'from': 'P22415', 'to': 'USF1'}, {'from': 'Q9NZJ4', 'to': 'SACS'}, {'from': 'Q9UNE7', 'to': 'STUB1'}, {'from': 'P04275', 'to': 'VWF'}, {'from': 'P32191', 'to': 'GUT2'}, {'from': 'Q9H6R6', 'to': 'ZDHHC6'}, {'from': 'Q9BV73', 'to': 'CEP250'}, {'from': 'P98161', 'to': 'PKD1'}, {'from': 'Q99LB2', 'to': 'Dhrs4'}, {'from': 'P11177', 'to': 'PDHB'}, {'from': 'P09917', 'to': 'ALOX5'}, {'from': 'P08067', 'to': 'RIP1'}, {'from': 'P42704', 'to': 'LRPPRC'}, {'from': 'P16871', 'to': 'IL7R'}, {'from': 'P11836', 'to': 'MS4A1'}, {'from': 'P52566', 'to': 'ARHGDIB'}, {'from': 'P12319', 'to': 'FCER1A'}, {'from': 'P49901', 'to': 'SMCP'}, {'from': 'P53010', 'to': 'PAN2'}, {'from': 'Q14126', 'to': 'DSG2'}, {'from': 'O15360', 'to': 'FANCA'}, {'from': 'Q9NRF9', 'to': 'POLE3'}, {'from': 'Q64FW2', 'to': 'Retsat'}, {'from': 'P21730', 'to': 'C5AR1'}, {'from': 'P50897', 'to': 'PPT1'}, {'from': 'Q12805', 'to': 'EFEMP1'}, {'from': 'P19634', 'to': 'SLC9A1'}, {'from': 'P15822', 'to': 'HIVEP1'}, {'from': 'P41221', 'to': 'WNT5A'}, {'from': 'Q29DI0', 'to': 'rept'}, {'from': 'Q9UKY1', 'to': 'ZHX1'}, {'from': 'Q02878', 'to': 'RPL6'}, {'from': 'Q9H4K1', 'to': 'RIBC2'}, {'from': 'P49354', 'to': 'FNTA'}, {'from': 'O15294', 'to': 'OGT'}, {'from': 'Q15119', 'to': 'PDK2'}, {'from': 'Q01970', 'to': 'PLCB3'}, {'from': 'Q9UNS2', 'to': 'COPS3'}, {'from': 'P39984', 'to': 'HAT2'}, {'from': 'Q13588', 'to': 'GRAP'}, {'from': 'P12643', 'to': 'BMP2'}, {'from': 'Q9UHV7', 'to': 'MED13'}, {'from': 'P19474', 'to': 'TRIM21'}, {'from': 'Q8WN66', 'to': 'ANG'}, {'from': 'Q9UID5', 'to': 'hREV3'}, {'from': 'Q13325', 'to': 'IFIT5'}, {'from': 'P35658', 'to': 'NUP214'}, {'from': 'Q96J01', 'to': 'THOC3'}, {'from': 'P15056', 'to': 'BRAF'}, {'from': 'Q12788', 'to': 'TBL3'}, {'from': 'P26659', 'to': 'rad15'}, {'from': 'P47224', 'to': 'RABIF'}, {'from': 'P37837', 'to': 'TALDO1'}, {'from': 'P36980', 'to': 'CFHR2'}, {'from': 'Q8TEM1', 'to': 'NUP210'}, {'from': 'P06168', 'to': 'ILV5'}, {'from': 'P55795', 'to': 'HNRNPH2'}, {'from': 'Q99638', 'to': 'RAD9A'}, {'from': 'O75716', 'to': 'STK16'}, {'from': 'Q5D1E8', 'to': 'ZC3H12A'}, {'from': 'Q9NRR4', 'to': 'DROSHA'}, {'from': 'P01906', 'to': 'HLA-DQA2'}, {'from': 'Q14654', 'to': 'KCNJ11'}, {'from': 'O95822', 'to': 'MLYCD'}, {'from': 'Q9UPY8', 'to': 'MAPRE3'}, {'from': 'Q9NYS7', 'to': 'WSB2'}, {'from': 'Q12996', 'to': 'CSTF3'}, {'from': 'P21246', 'to': 'PTN'}, {'from': 'Q96S99', 'to': 'PLEKHF1'}, {'from': 'P22303', 'to': 'ACHE'}, {'from': 'P49711', 'to': 'CTCF'}, {'from': 'O75379', 'to': 'VAMP4'}, {'from': 'O75095', 'to': 'MEGF6'}, {'from': 'P46108', 'to': 'CRK'}, {'from': 'O00167', 'to': 'EYA2'}, {'from': 'P20645', 'to': 'M6PR'}, {'from': 'O95751', 'to': 'LDOC1'}, {'from': 'Q6DKK2', 'to': 'TTC19'}, {'from': 'P13984', 'to': 'GTF2F2'}, {'from': 'O15105', 'to': 'SMAD7'}, {'from': 'Q91ZX6', 'to': 'Senp2'}, {'from': 'P22057', 'to': 'Ptgds'}, {'from': 'Q02223', 'to': 'TNFRSF17'}, {'from': 'Q5XG87', 'to': 'TENT4A'}, {'from': 'P60900', 'to': 'PSMA6'}, {'from': 'Q9ULA0', 'to': 'DNPEP'}, {'from': 'P05549', 'to': 'TFAP2A'}, {'from': 'Q07352', 'to': 'ZFP36L1'}, {'from': 'P60520', 'to': 'GABARAPL2'}, {'from': 'Q8IZ08', 'to': 'GPR135'}, {'from': 'Q96ST3', 'to': 'SIN3A'}, {'from': 'P51617', 'to': 'IRAK1'}, {'from': 'Q9UPZ9', 'to': 'CILK1'}, {'from': 'Q60452', 'to': 'ERCC2'}, {'from': 'Q9NTN9', 'to': 'SEMA4G'}, {'from': 'P78337', 'to': 'PITX1'}, {'from': 'P38631', 'to': 'FKS1'}, {'from': 'Q03135', 'to': 'CAV1'}, {'from': 'P07737', 'to': 'PFN1'}, {'from': 'P04179', 'to': 'SOD2'}, {'from': 'P61421', 'to': 'ATP6V0D1'}, {'from': 'Q15185', 'to': 'PTGES3'}, {'from': 'P0C7A3', 'to': 'Mboat4'}, {'from': 'P40259', 'to': 'CD79B'}, {'from': 'P58215', 'to': 'LOXL3'}, {'from': 'P13693', 'to': 'TPT1'}, {'from': 'Q14692', 'to': 'BMS1'}, {'from': 'Q99 ...
# ---------------------------------------------------------------------------
# IdMappingError                            Traceback (most recent call last)
# Cell In [59], line 9
#       5 request = IdMappingClient.submit(
#       6     source="UniProtKB_AC-ID",  dest="Gene_Name", ids={uid}
#       7 )
#       8 time.sleep(3.0)
# ----> 9 mappings.extend(list(request.each_result()))
#      10 print(mappings)
#
# File c:\Users\jaj146\Projects\Fall 22\GO_Annotation_of_Text\venv\lib\site-packages\unipressed\id_mapping\core.py:82, in IdMappingJob.each_result(self)
#      <a href='file:///c%3A/Users/jaj146/Projects/Fall%2022/GO_Annotation_of_Text/venv/lib/site-packages/unipressed/id_mapping/core.py?line=79'>80</a> parsed = page.json()
#      <a href='file:///c%3A/Users/jaj146/Projects/Fall%2022/GO_Annotation_of_Text/venv/lib/site-packages/unipressed/id_mapping/core.py?line=80'>81</a> if "results" not in parsed:
# ---> <a href='file:///c%3A/Users/jaj146/Projects/Fall%2022/GO_Annotation_of_Text/venv/lib/site-packages/unipressed/id_mapping/core.py?line=81'>82</a>     raise IdMappingError(
#      <a href='file:///c%3A/Users/jaj146/Projects/Fall%2022/GO_Annotation_of_Text/venv/lib/site-packages/unipressed/id_mapping/core.py?line=82'>83</a>         "UniProt has not yet processed the results, consider using time.sleep() to wait until they are complete."
#      <a href='file:///c%3A/Users/jaj146/Projects/Fall%2022/GO_Annotation_of_Text/venv/lib/site-packages/unipressed/id_mapping/core.py?line=83'>84</a>     )
#      <a href='file:///c%3A/Users/jaj146/Projects/Fall%2022/GO_Annotation_of_Text/venv/lib/site-packages/unipressed/id_mapping/core.py?line=84'>85</a> else:
#      <a href='file:///c%3A/Users/jaj146/Projects/Fall%2022/GO_Annotation_of_Text/venv/lib/site-packages/unipressed/id_mapping/core.py?line=85'>86</a>     yield from parsed["results"]
#
# IdMappingError: UniProt has not yet processed the results, consider using time.sleep() to wait until they are complete.
